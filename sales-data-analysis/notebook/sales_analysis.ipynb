# %%
# Sales Data Analysis - Sample Superstore

## Objective
This project analyzes a retail sales dataset to identify:
- the most profitable product category
- the highest performing region
- the best performing months
- key business insights from sales and profit trends

## Tools Used
- Python
- Pandas
- Matplotlib
- Seaborn
# Out:
#   Cell In[2], line 4
#     This project analyzes a retail sales dataset to identify:
#          ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Optional styling
sns.set_style("whitegrid")
plt.rcParams["figure.figsize"] = (10, 6)

# %%
df = pd.read_csv("data/superstore.csv", encoding="ISO-8859-1")
df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df = pd.read_csv("data/superstore.csv", encoding="ISO-8859-1")
#       2 df.head()
#
# NameError: name 'pd' is not defined
